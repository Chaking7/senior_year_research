# %%
notes = ''' 

Sci kit learn classes to pick a model, generate a dummy set etc

Oliver: 
The external optimization loop should be optimizing over the 'model parameters'. So in that example they initialize the model with SVC() using 
all default parameters. But you should also be able to find better model parameters for the task at hand - that's what optuna, etc. are doing 
for you. So notice how the model itself is well packaged in that loop, with just model.init(), model.fit(), model.score() methods exposed. 
The trick for us will be to decide how to package this whole training loop in a similarly compact fashion - it's just one more meta layer of 
abstraction - so that the optuna or ray optimization framework can do their work in a similarly small number of lines of code.


Then the trick will be - it won't actually always be a neural network in the inner loop. We can sub in a physics based model, or a full multiphysics
simulation, or even a live real-world process. If the packaging is the same, then the same code and tools can be re-used.
Looking ahead, we can make some assumptions. You can assume we'll always have a .score() objective function, and that the goal will always be to minimize 
that number. You can also assume that the parameter input to the loop will be a dictionary, and the method should be flexible to a variable number of
parameters in the dictionary.

'''

from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

import optuna

# Hope this isnt a terrible thing to do, create a virtual environment
# next time to add packages
# import sys
# !{sys.executable} -m pip install packaging==21.0

# !{sys.executable} -m pip install 'ray[tune]'

######### Quick start optuna example ####################################

def objective(trial):
    x = trial.suggest_uniform('x', -10, 10)
    return (x-2)**2

study = optuna.create_study()
study.optimize(objective, n_trials=100)

study.best_params

############################### Ray quick start example ############################################

from ray import tune


def objective(step, alpha, beta):
    return (0.1 + alpha * step / 100)**(-1) + beta * 0.1


def training_function(config):
    # Hyperparameters
    alpha, beta = config["alpha"], config["beta"]
    for step in range(10):
        # Iterative training function - can be any arbitrary training procedure.
        intermediate_score = objective(step, alpha, beta)
        # Feed the score back back to Tune.
        tune.report(mean_loss=intermediate_score)


analysis = tune.run(
    training_function,
    config={
        "alpha": tune.grid_search([0.001, 0.01, 0.1]),
        "beta": tune.choice([1, 2, 3])
    })

print("Best config: ", analysis.get_best_config(
    metric="mean_loss", mode="min"))

# Get a dataframe for analyzing trial results.
df = analysis.results_df

################## Pipeline tutorial ##########################
x, y =  make_classification(random_state=0)
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# SVC is default right here but we want to find better parameters with optuna right
# here instead
pipe = Pipeline([('scalar', StandardScaler()), ('svc', SVC())])

pipe.fit(x_train, y_train)
pipe.score(x_test, y_test)

#################################################################
    
    
print("All GOOD")
# Out:
# [I 2021-10-11 00:04:03,635] A new study created in memory with name: no-name-c48959eb-50cb-4522-9e8a-9e1b7692de20
# [I 2021-10-11 00:04:03,638] Trial 0 finished with value: 8.707704130823227 and parameters: {'x': -0.9508819242428572}. Best is trial 0 with value: 8.707704130823227.
# [I 2021-10-11 00:04:03,639] Trial 1 finished with value: 19.141254978241786 and parameters: {'x': 6.375071996920941}. Best is trial 0 with value: 8.707704130823227.
# [I 2021-10-11 00:04:03,641] Trial 2 finished with value: 47.14418702095881 and parameters: {'x': 8.866162466833917}. Best is trial 0 with value: 8.707704130823227.
# [I 2021-10-11 00:04:03,642] Trial 3 finished with value: 1.134422058959872 and parameters: {'x': 3.065092511925547}. Best is trial 3 with value: 1.134422058959872.
# [I 2021-10-11 00:04:03,643] Trial 4 finished with value: 1.5641129736034314 and parameters: {'x': 3.2506450230194943}. Best is trial 3 with value: 1.134422058959872.
# [I 2021-10-11 00:04:03,644] Trial 5 finished with value: 0.9312056429283014 and parameters: {'x': 2.964989970377051}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,645] Trial 6 finished with value: 1.0119464504720603 and parameters: {'x': 3.0059554912977315}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,647] Trial 7 finished with value: 13.85840655298257 and parameters: {'x': -1.722688081612878}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,649] Trial 8 finished with value: 97.76269954347885 and parameters: {'x': -7.887502189303365}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,651] Trial 9 finished with value: 143.288797191926 and parameters: {'x': -9.970329869804173}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,654] Trial 10 finished with value: 38.070476082862456 and parameters: {'x': -4.170127720141817}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,657] Trial 11 finished with value: 1.2810325410121357 and parameters: {'x': 3.131827080879467}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,660] Trial 12 finished with value: 13.32096215999791 and parameters: {'x': 5.649789330906362}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,663] Trial 13 finished with value: 1.2173137991261456 and parameters: {'x': 0.8966805543605489}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,666] Trial 14 finished with value: 34.69300872725507 and parameters: {'x': -3.890077141027532}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,669] Trial 15 finished with value: 51.22772915639766 and parameters: {'x': 9.157354899430212}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,672] Trial 16 finished with value: 13.730009371608135 and parameters: {'x': 5.705402727316983}. Best is trial 5 with value: 0.9312056429283014.
# [I 2021-10-11 00:04:03,674] Trial 17 finished with value: 0.8574891479288262 and parameters: {'x': 1.0739929007135927}. Best is trial 17 with value: 0.8574891479288262.
# [I 2021-10-11 00:04:03,677] Trial 18 finished with value: 1.6134673247511566 and parameters: {'x': 0.7297766634362457}. Best is trial 17 with value: 0.8574891479288262.
# [I 2021-10-11 00:04:03,680] Trial 19 finished with value: 23.31411142603238 and parameters: {'x': -2.828468849027855}. Best is trial 17 with value: 0.8574891479288262.
# [I 2021-10-11 00:04:03,683] Trial 20 finished with value: 80.11236762748614 and parameters: {'x': -6.950551247129203}. Best is trial 17 with value: 0.8574891479288262.
# [I 2021-10-11 00:04:03,686] Trial 21 finished with value: 0.1261068725790226 and parameters: {'x': 1.6448847052307904}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,688] Trial 22 finished with value: 0.3870979975592769 and parameters: {'x': 1.3778280000198684}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,692] Trial 23 finished with value: 1.0744388708105175 and parameters: {'x': 0.9634485681788301}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,695] Trial 24 finished with value: 5.851080871915015 and parameters: {'x': -0.4189007569379555}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,699] Trial 25 finished with value: 7.653428638322937 and parameters: {'x': 4.766483081156098}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,701] Trial 26 finished with value: 0.40262170049862434 and parameters: {'x': 1.3654752167971496}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,705] Trial 27 finished with value: 30.47249621745107 and parameters: {'x': 7.520189871503613}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,708] Trial 28 finished with value: 14.91054762598567 and parameters: {'x': -1.8614178258750596}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,712] Trial 29 finished with value: 9.745652881197119 and parameters: {'x': -1.1218028254835566}. Best is trial 21 with value: 0.1261068725790226.
# [I 2021-10-11 00:04:03,716] Trial 30 finished with value: 0.020338886991906523 and parameters: {'x': 1.8573855302155264}. Best is trial 30 with value: 0.020338886991906523.
# [I 2021-10-11 00:04:03,720] Trial 31 finished with value: 0.01409205014289533 and parameters: {'x': 2.118709941213427}. Best is trial 31 with value: 0.01409205014289533.
# [I 2021-10-11 00:04:03,725] Trial 32 finished with value: 7.159415423018769 and parameters: {'x': 4.675708396484708}. Best is trial 31 with value: 0.01409205014289533.
# [I 2021-10-11 00:04:03,729] Trial 33 finished with value: 6.675625046506765 and parameters: {'x': 4.583723097877705}. Best is trial 31 with value: 0.01409205014289533.
# [I 2021-10-11 00:04:03,733] Trial 34 finished with value: 0.0001320771726277468 and parameters: {'x': 1.9885075166901254}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,739] Trial 35 finished with value: 0.04413265751838898 and parameters: {'x': 2.210077741606266}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,744] Trial 36 finished with value: 27.37979852205107 and parameters: {'x': 7.232570928525582}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,750] Trial 37 finished with value: 0.08011794085354262 and parameters: {'x': 2.2830511276316394}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,754] Trial 38 finished with value: 4.155881266545887 and parameters: {'x': 4.038597867787045}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,758] Trial 39 finished with value: 4.808177240167849 and parameters: {'x': -0.19275562709752259}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,761] Trial 40 finished with value: 0.2578283779777051 and parameters: {'x': 2.5077680356006127}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,764] Trial 41 finished with value: 0.15241224487283536 and parameters: {'x': 2.390400108699825}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,767] Trial 42 finished with value: 3.383933717398988 and parameters: {'x': 3.8395471500885723}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,770] Trial 43 finished with value: 0.00035572425348387194 and parameters: {'x': 1.9811393464194935}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,773] Trial 44 finished with value: 3.749725337271707 and parameters: {'x': 0.06357924580640084}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,776] Trial 45 finished with value: 2.4034536153262827 and parameters: {'x': 3.5503075873278447}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,779] Trial 46 finished with value: 10.873860061357806 and parameters: {'x': -1.297553647987824}. Best is trial 34 with value: 0.0001320771726277468.
# [I 2021-10-11 00:04:03,782] Trial 47 finished with value: 8.582224516938563e-06 and parameters: {'x': 1.9970704566026531}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,785] Trial 48 finished with value: 13.162263259846823 and parameters: {'x': 5.627983359918678}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,789] Trial 49 finished with value: 3.184566715661867 and parameters: {'x': 0.21546456587103124}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,792] Trial 50 finished with value: 16.870897156062675 and parameters: {'x': -2.10741976867019}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,795] Trial 51 finished with value: 0.002602488393354761 and parameters: {'x': 2.05101459000477}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,797] Trial 52 finished with value: 0.7162894678703603 and parameters: {'x': 2.8463388611368146}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,800] Trial 53 finished with value: 0.04993361927847151 and parameters: {'x': 1.7765416833535357}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,803] Trial 54 finished with value: 2.3322767876233805 and parameters: {'x': 0.472820643269632}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,806] Trial 55 finished with value: 1.756328214409528 and parameters: {'x': 3.3252653373606087}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,809] Trial 56 finished with value: 7.962009979136311 and parameters: {'x': -0.8217033825574775}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,812] Trial 57 finished with value: 3.984876884323701 and parameters: {'x': 3.9962156407371676}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,815] Trial 58 finished with value: 0.03778075754570034 and parameters: {'x': 1.8056272715998967}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,819] Trial 59 finished with value: 18.21405011914899 and parameters: {'x': 6.267792183219444}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,822] Trial 60 finished with value: 0.971757167061461 and parameters: {'x': 2.985777442966444}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,825] Trial 61 finished with value: 0.00725337809341153 and parameters: {'x': 1.9148332336329978}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,828] Trial 62 finished with value: 1.281141975932193 and parameters: {'x': 0.8681245757892819}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,832] Trial 63 finished with value: 0.06541848567014909 and parameters: {'x': 1.7442296231575105}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,835] Trial 64 finished with value: 1.919789879638817 and parameters: {'x': 0.614435176673853}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,838] Trial 65 finished with value: 5.257449493661887 and parameters: {'x': -0.29291288401061744}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,842] Trial 66 finished with value: 24.64207106547705 and parameters: {'x': -2.964078068028045}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,846] Trial 67 finished with value: 8.425347026756263 and parameters: {'x': 4.902644833036978}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,849] Trial 68 finished with value: 0.7331974377787858 and parameters: {'x': 2.8562694889920963}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,853] Trial 69 finished with value: 0.4683726747160409 and parameters: {'x': 1.3156224180205485}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,857] Trial 70 finished with value: 0.028530008293364877 and parameters: {'x': 2.1689082836730185}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,863] Trial 71 finished with value: 0.13296484338299933 and parameters: {'x': 2.364643446921783}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,869] Trial 72 finished with value: 0.014520564127675474 and parameters: {'x': 2.1205013034272886}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,872] Trial 73 finished with value: 2.3019087789869013 and parameters: {'x': 3.5172042640946213}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,876] Trial 74 finished with value: 0.9495485711618535 and parameters: {'x': 1.0255521711441635}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,881] Trial 75 finished with value: 0.11583481746799035 and parameters: {'x': 1.6596548553776764}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,885] Trial 76 finished with value: 6.564940059324153 and parameters: {'x': -0.5622138980428921}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,889] Trial 77 finished with value: 61.93829748328741 and parameters: {'x': 9.870088784968528}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,893] Trial 78 finished with value: 5.319184950346677 and parameters: {'x': 4.306335827746401}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,897] Trial 79 finished with value: 10.46871201693479 and parameters: {'x': 5.235538906725553}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,901] Trial 80 finished with value: 0.48138366140519256 and parameters: {'x': 2.6938181760412396}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,907] Trial 81 finished with value: 0.010153543858198054 and parameters: {'x': 2.100764794736049}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,912] Trial 82 finished with value: 1.619656080165322 and parameters: {'x': 3.272657094493769}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,917] Trial 83 finished with value: 0.017660694722869852 and parameters: {'x': 2.1328935465809753}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,923] Trial 84 finished with value: 2.485520183326858 and parameters: {'x': 0.4234467394576047}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,927] Trial 85 finished with value: 0.8973887075648844 and parameters: {'x': 1.0526939736469083}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,936] Trial 86 finished with value: 135.6586379540862 and parameters: {'x': -9.647258817167506}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,948] Trial 87 finished with value: 0.013603972496026783 and parameters: {'x': 2.1166360685895524}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,963] Trial 88 finished with value: 0.5787464039814617 and parameters: {'x': 1.239246160718553}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,972] Trial 89 finished with value: 3.579768600610507 and parameters: {'x': 3.8920276426655365}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,981] Trial 90 finished with value: 0.3732136555344799 and parameters: {'x': 2.610912150423021}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,994] Trial 91 finished with value: 0.019120013785581116 and parameters: {'x': 1.8617248620120699}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:03,999] Trial 92 finished with value: 0.04415395453841702 and parameters: {'x': 2.210128423918367}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,004] Trial 93 finished with value: 3.6857269441944807 and parameters: {'x': 0.08017528295042498}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,010] Trial 94 finished with value: 1.9693868123394411 and parameters: {'x': 3.403348428701668}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,015] Trial 95 finished with value: 1.1135786582544107 and parameters: {'x': 3.055262364653649}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,020] Trial 96 finished with value: 0.010236211843318306 and parameters: {'x': 2.101174165888918}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,025] Trial 97 finished with value: 0.3400319986615527 and parameters: {'x': 1.4168773725351136}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,030] Trial 98 finished with value: 2.0298955986814313 and parameters: {'x': 0.5752559532739112}. Best is trial 47 with value: 8.582224516938563e-06.
# [I 2021-10-11 00:04:04,037] Trial 99 finished with value: 5.144586390607616 and parameters: {'x': 4.268168069303423}. Best is trial 47 with value: 8.582224516938563e-06.
# 2021-10-11 00:04:09,669	WARNING function_runner.py:559 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Memory usage on this node: 10.7/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/4.37 GiB heap, 0.0/2.18 GiB objects<br>Result logdir: /Users/chaking/ray_results/training_function_2021-10-11_00-04-09<br>Number of trials: 3/3 (3 PENDING)<br><table>
# <thead>
# <tr><th>Trial name                   </th><th>status  </th><th>loc  </th><th style="text-align: right;">  alpha</th><th style="text-align: right;">  beta</th></tr>
# </thead>
# <tbody>
# <tr><td>training_function_6e905_00000</td><td>PENDING </td><td>     </td><td style="text-align: right;">  0.001</td><td style="text-align: right;">     1</td></tr>
# <tr><td>training_function_6e905_00001</td><td>PENDING </td><td>     </td><td style="text-align: right;">  0.01 </td><td style="text-align: right;">     2</td></tr>
# <tr><td>training_function_6e905_00002</td><td>PENDING </td><td>     </td><td style="text-align: right;">  0.1  </td><td style="text-align: right;">     2</td></tr>
# </tbody>
# </table><br><br>
# Result for training_function_6e905_00000:
#   date: 2021-10-11_00-04-15
#   done: false
#   experiment_id: 0e77cd13f0c6460aa5c52d124a9cad28
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_loss: 10.1
#   neg_mean_loss: -10.1
#   node_ip: 10.0.0.180
#   pid: 30718
#   time_since_restore: 8.177757263183594e-05
#   time_this_iter_s: 8.177757263183594e-05
#   time_total_s: 8.177757263183594e-05
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6e905_00000
#
# Result for training_function_6e905_00001:
#   date: 2021-10-11_00-04-15
#   done: false
#   experiment_id: a20980cd3d4a491980fca4f82fbe1f37
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_loss: 10.2
#   neg_mean_loss: -10.2
#   node_ip: 10.0.0.180
#   pid: 30725
#   time_since_restore: 8.702278137207031e-05
#   time_this_iter_s: 8.702278137207031e-05
#   time_total_s: 8.702278137207031e-05
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6e905_00001
#
# Result for training_function_6e905_00002:
#   date: 2021-10-11_00-04-15
#   done: false
#   experiment_id: 510911f6cdf142ccbb588a21cdb9ebb6
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 1
#   mean_loss: 10.2
#   neg_mean_loss: -10.2
#   node_ip: 10.0.0.180
#   pid: 30723
#   time_since_restore: 7.295608520507812e-05
#   time_this_iter_s: 7.295608520507812e-05
#   time_total_s: 7.295608520507812e-05
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6e905_00002
#
# Result for training_function_6e905_00001:
#   date: 2021-10-11_00-04-15
#   done: true
#   experiment_id: a20980cd3d4a491980fca4f82fbe1f37
#   experiment_tag: 1_alpha=0.01,beta=2
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 10
#   mean_loss: 10.110802775024776
#   neg_mean_loss: -10.110802775024776
#   node_ip: 10.0.0.180
#   pid: 30725
#   time_since_restore: 0.04126381874084473
#   time_this_iter_s: 0.005169868469238281
#   time_total_s: 0.04126381874084473
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 6e905_00001
#
# Result for training_function_6e905_00002:
#   date: 2021-10-11_00-04-15
#   done: true
#   experiment_id: 510911f6cdf142ccbb588a21cdb9ebb6
#   experiment_tag: 2_alpha=0.1,beta=2
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 10
#   mean_loss: 9.374311926605502
#   neg_mean_loss: -9.374311926605502
#   node_ip: 10.0.0.180
#   pid: 30723
#   time_since_restore: 0.04927682876586914
#   time_this_iter_s: 0.0033347606658935547
#   time_total_s: 0.04927682876586914
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 6e905_00002
#
# Result for training_function_6e905_00000:
#   date: 2021-10-11_00-04-15
#   done: true
#   experiment_id: 0e77cd13f0c6460aa5c52d124a9cad28
#   experiment_tag: 0_alpha=0.001,beta=1
#   hostname: Chandlers-MacBook-Pro.local
#   iterations_since_restore: 10
#   mean_loss: 10.091008092716553
#   neg_mean_loss: -10.091008092716553
#   node_ip: 10.0.0.180
#   pid: 30718
#   time_since_restore: 0.061543941497802734
#   time_this_iter_s: 0.013457059860229492
#   time_total_s: 0.061543941497802734
#   timestamp: 1633935855
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 6e905_00000
# == Status ==<br>Memory usage on this node: 10.6/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/0 GPUs, 0.0/4.37 GiB heap, 0.0/2.18 GiB objects<br>Result logdir: /Users/chaking/ray_results/training_function_2021-10-11_00-04-09<br>Number of trials: 3/3 (3 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc  </th><th style="text-align: right;">  alpha</th><th style="text-align: right;">  beta</th><th style="text-align: right;">    loss</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  neg_mean_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>training_function_6e905_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">  0.001</td><td style="text-align: right;">     1</td><td style="text-align: right;">10.091  </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0615439</td><td style="text-align: right;">      -10.091  </td></tr>
# <tr><td>training_function_6e905_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">  0.01 </td><td style="text-align: right;">     2</td><td style="text-align: right;">10.1108 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0412638</td><td style="text-align: right;">      -10.1108 </td></tr>
# <tr><td>training_function_6e905_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">  0.1  </td><td style="text-align: right;">     2</td><td style="text-align: right;"> 9.37431</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0492768</td><td style="text-align: right;">       -9.37431</td></tr>
# </tbody>
# </table><br><br>
# 2021-10-11 00:04:15,329	INFO tune.py:617 -- Total run time: 5.66 seconds (2.21 seconds for the tuning loop).
# Best config:  {'alpha': 0.1, 'beta': 2}
# All GOOD

# %%
import sklearn
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, make_pipeline

import optuna

from ray import tune

def objective(trial):
    # questions I have going into this
    # where exactly does the ray optimization fall????
    # Should I be using optima separaretly or ask about the tuning
    # from ray with bayesiain optimization
    
    # do I like edit the hyperparameters with optuna and then immdediately run
    # configurations from ray??
    
    # 
    svc_c = trial.suggest_float('svc_c',1e-10, 1e10, log=True)
    
    x, y =  make_classification(random_state=0)
    # x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
    
    # does this update the SVC like I am attempting or did that not accomplish anything
    obj = sklearn.svm.SVC(C=svc_c, gamma='auto')
    # pipe = Pipeline([('scalar', StandardScaler()), ('svc', SVC())])
    score = sklearn.model_selection.cross_val_score(obj, x, y, n_jobs=-1, cv=3)
    accuracy = score.mean()
    
    
    # pipe.fit(x_train, y_train)
    # ans = pipe.score(x_test, y_test)
    
    return accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
print(study.best_trial)
# Out:
# [I 2021-10-11 12:10:17,527] A new study created in memory with name: no-name-5bff78ee-8f20-47ce-8efa-8a2eae8fa66c
# [I 2021-10-11 12:10:19,448] Trial 0 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.3915284479755351e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:19,974] Trial 1 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0003787161276670669}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,420] Trial 2 finished with value: 0.8094362745098039 and parameters: {'svc_c': 296.96463475911264}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,858] Trial 3 finished with value: 0.8094362745098039 and parameters: {'svc_c': 64.86388396956013}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,867] Trial 4 finished with value: 0.8094362745098039 and parameters: {'svc_c': 3.56172040135159}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,877] Trial 5 finished with value: 0.8094362745098039 and parameters: {'svc_c': 66214688.4266147}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,885] Trial 6 finished with value: 0.8094362745098039 and parameters: {'svc_c': 160.87357416752607}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,894] Trial 7 finished with value: 0.8094362745098039 and parameters: {'svc_c': 64.43089621750892}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,905] Trial 8 finished with value: 0.8094362745098039 and parameters: {'svc_c': 81261.11186742237}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,918] Trial 9 finished with value: 0.8094362745098039 and parameters: {'svc_c': 845004146.7289655}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,930] Trial 10 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.0689664190257809e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,942] Trial 11 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.1018011036313887e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,956] Trial 12 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00023390099123147387}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,968] Trial 13 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0017778773861372283}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,980] Trial 14 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.4220629451894903e-08}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:20,992] Trial 15 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.220839808134122e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,005] Trial 16 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.06271347379739653}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,017] Trial 17 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.1800971632610297e-10}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,032] Trial 18 finished with value: 0.8406862745098039 and parameters: {'svc_c': 4.5358401749631083e-07}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,496] Trial 19 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.005022616963153858}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,506] Trial 20 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.080508598222803e-10}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,516] Trial 21 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.6810487563804232e-07}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,525] Trial 22 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.05018828144934176}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:21,533] Trial 23 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.1765478017824928e-10}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,067] Trial 24 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.3442168799554923e-07}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,076] Trial 25 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.138406927274011e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,085] Trial 26 finished with value: 0.8094362745098039 and parameters: {'svc_c': 1.7321020981822441}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,095] Trial 27 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.0606275449393437e-08}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,107] Trial 28 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.514110975938585e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,118] Trial 29 finished with value: 0.8406862745098039 and parameters: {'svc_c': 5.093017113690132e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,129] Trial 30 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.752971596279448e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,600] Trial 31 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.3933527187285678e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,609] Trial 32 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00010099920018739035}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,621] Trial 33 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.105547783907014e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,632] Trial 34 finished with value: 0.8406862745098039 and parameters: {'svc_c': 9.155237009894221e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,642] Trial 35 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0004804875460822617}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,653] Trial 36 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.09586244671377447}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,664] Trial 37 finished with value: 0.8094362745098039 and parameters: {'svc_c': 2882.5387295504347}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,677] Trial 38 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.023091950548686287}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,688] Trial 39 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.8703778062138984e-07}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,699] Trial 40 finished with value: 0.8094362745098039 and parameters: {'svc_c': 11.406085765755275}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,709] Trial 41 finished with value: 0.8406862745098039 and parameters: {'svc_c': 6.596565009649725e-08}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,720] Trial 42 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.1862783296142342e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,730] Trial 43 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.0061740614812119e-10}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,740] Trial 44 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.1372862122216916e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,753] Trial 45 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.1360299673123633e-08}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,764] Trial 46 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.842573881065218e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,774] Trial 47 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.7593485729236566e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:22,786] Trial 48 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.002063119147399565}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,267] Trial 49 finished with value: 0.8094362745098039 and parameters: {'svc_c': 4910320.9860696895}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,277] Trial 50 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00011699035301322689}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,287] Trial 51 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.869861565204724e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,298] Trial 52 finished with value: 0.8406862745098039 and parameters: {'svc_c': 4.1413771259255964e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,309] Trial 53 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.0180944108159874e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,319] Trial 54 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0005384752126434133}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,330] Trial 55 finished with value: 0.8406862745098039 and parameters: {'svc_c': 8.842220826879545e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,341] Trial 56 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.4323982521701943e-06}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,351] Trial 57 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.010704568454725335}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,362] Trial 58 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.444793578054656e-05}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,373] Trial 59 finished with value: 0.8406862745098039 and parameters: {'svc_c': 8.264397928940247e-09}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,383] Trial 60 finished with value: 0.829656862745098 and parameters: {'svc_c': 0.2506274846126495}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,394] Trial 61 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00043723501166407694}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,405] Trial 62 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.024088590400265203}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,416] Trial 63 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.000346061075457808}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,426] Trial 64 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.10113697756358653}. Best is trial 0 with value: 0.8406862745098039.
# [I 2021-10-11 12:10:23,437] Trial 65 finished with value: 0.8504901960784313 and parameters: {'svc_c': 0.7923180575562476}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,447] Trial 66 finished with value: 0.8400735294117646 and parameters: {'svc_c': 0.4637718856222399}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,459] Trial 67 finished with value: 0.8094362745098039 and parameters: {'svc_c': 31.6960684491793}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,470] Trial 68 finished with value: 0.8094362745098039 and parameters: {'svc_c': 5.878294470295355}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,481] Trial 69 finished with value: 0.8094362745098039 and parameters: {'svc_c': 544.5033710213003}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,492] Trial 70 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.002335421585004339}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,502] Trial 71 finished with value: 0.8406862745098039 and parameters: {'svc_c': 8.228523290790684e-08}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,513] Trial 72 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0025836022822002067}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,524] Trial 73 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.943786566104428e-10}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,535] Trial 74 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.953341469741947e-07}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,546] Trial 75 finished with value: 0.8406862745098039 and parameters: {'svc_c': 6.026203496282085e-10}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,557] Trial 76 finished with value: 0.8406862745098039 and parameters: {'svc_c': 2.7147165735730328e-08}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,568] Trial 77 finished with value: 0.8406862745098039 and parameters: {'svc_c': 8.477985020644739e-06}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,580] Trial 78 finished with value: 0.8406862745098039 and parameters: {'svc_c': 5.453344093515429e-07}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,597] Trial 79 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.233542845527607e-07}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,609] Trial 80 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0006417521621582649}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:23,621] Trial 81 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.360934651538765e-05}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,144] Trial 82 finished with value: 0.8406862745098039 and parameters: {'svc_c': 6.678851236028977e-06}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,153] Trial 83 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00556482394710915}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,165] Trial 84 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.7455404936343093e-06}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,177] Trial 85 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.009673617747347797}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,188] Trial 86 finished with value: 0.8406862745098039 and parameters: {'svc_c': 1.690422307369956e-06}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,199] Trial 87 finished with value: 0.8406862745098039 and parameters: {'svc_c': 3.6832138534991695e-05}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,209] Trial 88 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0001599851255692559}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,221] Trial 89 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0012005032704734656}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,231] Trial 90 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0326642181985868}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,241] Trial 91 finished with value: 0.8406862745098039 and parameters: {'svc_c': 7.44042288059435e-05}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,253] Trial 92 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.00025082773836046724}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,264] Trial 93 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.1451074703825955}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,274] Trial 94 finished with value: 0.8192401960784313 and parameters: {'svc_c': 1.2694487825204834}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,284] Trial 95 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.010781379896201143}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,297] Trial 96 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.056020710337360745}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,308] Trial 97 finished with value: 0.829656862745098 and parameters: {'svc_c': 0.3551606654129396}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,320] Trial 98 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0011940953199488093}. Best is trial 65 with value: 0.8504901960784313.
# [I 2021-10-11 12:10:24,331] Trial 99 finished with value: 0.8406862745098039 and parameters: {'svc_c': 0.0023798018562762304}. Best is trial 65 with value: 0.8504901960784313.
# FrozenTrial(number=65, values=[0.8504901960784313], datetime_start=datetime.datetime(2021, 10, 11, 12, 10, 23, 427324), datetime_complete=datetime.datetime(2021, 10, 11, 12, 10, 23, 436787), params={'svc_c': 0.7923180575562476}, distributions={'svc_c': LogUniformDistribution(high=10000000000.0, low=1e-10)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=65, state=TrialState.COMPLETE, value=None)
